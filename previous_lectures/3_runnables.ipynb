# %% [markdown]
# ### RunnablePassthrough, RunnableLambda, RunnableParallel

# %% [markdown]
# ##### Boilerplate Code

# %%
import langchain
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

load_dotenv()

google_api_key = os.getenv("GOOGLE_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")

google_llm = ChatGoogleGenerativeAI(
    temperature=0,
    model="gemini-2.0-flash", 
    api_key=google_api_key,
    max_tokens=200
)

openai_llm = ChatOpenAI(
    temperature=0, 
    model="gpt-4", 
    api_key=openai_api_key
)

# %% [markdown]
# ### Callable - plain Python function/lambda/class with __call__, can be executed with ()

# %%
# Callable
def add_one(x):
    return x + 1

add_two = lambda x: x + 2

print(add_one.__call__(1))
print(add_two.__call__(1))

# %%
# Runnable (wrapping callable)
from langchain.schema.runnable import RunnableLambda
runnable = RunnableLambda(add_two)

print(runnable.invoke(1))
# Out:
# 3

# %% [markdown]
# ### RunnablePassthrough - just echoes the input unchanged

# %%
from langchain_core.runnables import RunnablePassthrough

# Simple example - just passes data through
chain = RunnablePassthrough()
result = chain.invoke("Hello World")
print(result)
# Out:
# Hello World

# %%
# Adding extra data while keeping original
chain = RunnablePassthrough.assign(
    length=lambda x: len(x["text"]),
    upper=lambda x: x["text"].upper()
)

result = chain.invoke({"text": "Python"})
print(result)
# Out:
# {'text': 'Python', 'length': 6, 'upper': 'PYTHON'}

# %% [markdown]
# ### RunnableLambda - wraps a Python function as a runnable.

# %%
from langchain_core.runnables import RunnableLambda

# Simple function
def make_uppercase(text):
    return text.upper()

# Turn it into a Runnable
uppercase_step = RunnableLambda(make_uppercase)

result = uppercase_step.invoke("hello world")
print(result)
# Out:
# HELLO WORLD

# %%
# Chain multiple functions
def add_excitement(text):
    return text + "!!!"

chain = (
    RunnableLambda(make_uppercase) |  # First: make uppercase
    RunnableLambda(add_excitement)    # Then: add exclamation
)

result = chain.invoke("hello world")
print(result)
# Out:
# HELLO WORLD!!!

# %% [markdown]
# ### RunnableParallel - runs multiple runnables at the same time and merges results.

# %%
from langchain_core.runnables import RunnableParallel, RunnableLambda

# Define simple functions
def count_words(text):
    return len(text.split())

def count_chars(text):
    return len(text)

def make_uppercase(text):
    return text.upper()

# Run all functions at the same time on the same input
parallel = RunnableParallel(
    words=RunnableLambda(count_words),
    chars=RunnableLambda(count_chars),
    upper=RunnableLambda(make_uppercase)
)

input_text = "I love Python"
result = parallel.invoke(input_text)
print(result)

# %% [markdown]
# ### Merging all - RunnablePassthrough, RunnableLambda, RunnableParallel in single code

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda, RunnableParallel

# Simple functions
def count_words(text):
    return len(text.split())

def get_first_word(text):
    return text.split()[0]

# Build a simple chain
chain = (
    RunnablePassthrough.assign(
        analysis=RunnableParallel(
            word_count=RunnableLambda(lambda d: count_words(d["text"])),
            first_word=RunnableLambda(lambda d: get_first_word(d["text"]))
        )
    )
)

# Test it
result = chain.invoke({"text": "Python programming is fun"})
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 21
#      11 chain = (
#      12     RunnablePassthrough.assign(
#      13         analysis=RunnableParallel(
#    (...)
#      17     )
#      18 )
#      20 # Test it
# ---> 21 result = chain.invoke("Python programming is fun")
#      22 print(result)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/langchain_core/runnables/passthrough.py:511, in RunnableAssign.invoke(self, input, config, **kwargs)
#     504 @override
#     505 def invoke(
#     506     self,
#    (...)
#     509     **kwargs: Any,
#     510 ) -> dict[str, Any]:
# --> 511     return self._call_with_config(self._invoke, input, config, **kwargs)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/langchain_core/runnables/base.py:1930, in Runnable._call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1926     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1927     with set_config_context(child_config) as context:
#    1928         output = cast(
#    1929             "Output",
# -> 1930             context.run(
#    1931                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1932                 func,
#    1933                 input,
#    1934                 config,
#    1935                 run_manager,
#    1936                 **kwargs,
#    1937             ),
#    1938         )
#    1939 except BaseException as e:
#    1940     run_manager.on_chain_error(e)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/langchain_core/runnables/config.py:428, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     426 if run_manager is not None and accepts_run_manager(func):
#     427     kwargs["run_manager"] = run_manager
# --> 428 return func(input, **kwargs)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/langchain_core/runnables/passthrough.py:493, in RunnableAssign._invoke(self, input, run_manager, config, **kwargs)
#     491 if not isinstance(input, dict):
#     492     msg = "The input to RunnablePassthrough.assign() must be a dict."
# --> 493     raise ValueError(msg)  # noqa: TRY004
#     495 return {
#     496     **input,
#     497     **self.mapper.invoke(
#    (...)
#     501     ),
#     502 }
#
# ValueError: The input to RunnablePassthrough.assign() must be a dict.
