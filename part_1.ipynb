# %% [markdown]
# ### Langchain Introduction

# %% [markdown]
# ##### Boilerplate code

# %%
import langchain
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()

google_api_key = os.getenv("GOOGLE_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")

google_llm = ChatGoogleGenerativeAI(
    temperature=0, 
    model="gemini-2.0-flash", 
    api_key=google_api_key
)

openai_llm = ChatOpenAI(
    temperature=0, 
    model="gpt-4", 
    api_key=openai_api_key
)

# %%
prompt = PromptTemplate(
    input_variables=["country"],
    template="""
    You are a helpful assistant. Where is {country} located?. Give me a description about this country in 1 line.""",
)

# %%
chain = prompt | google_llm

# for s in chain.stream({"country": "India"}):
#     print(s)

res = chain.invoke({"country": "India"})

print(res.content, "\n")
# Out:
# India is located in South Asia.
#
# India is a vibrant and diverse country known for its rich history, cultural heritage, and rapidly growing economy.
